# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamsankranthi13-a11y/pandas-Data-Frames/blob/main/pandas_handling_missing_values1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8ddb5c7-beaa-47b1-a258-75c9367a41c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8ddb5c7-beaa-47b1-a258-75c9367a41c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#select single column
import pandas as pd
df = pd.read_csv("Sales1.tsv", sep="\t")
print(df.Product)
# Out:
# 0         34in Ultrawide Monitor
# 1                    Samsung m10
# 2                   20in Monitor
# 3                      iPhone 11
# 4             Macbook Pro Laptop
# 5     Bose SoundSport Headphones
# 6         27in 4K Gaming Monitor
# 7                    Samsung m10
# 8         34in Ultrawide Monitor
# 9                      iPhone 11
# 10                   Samsung m10
# 11            Macbook Pro Laptop
# 12               ThinkPad Laptop
# 13        27in 4K Gaming Monitor
# 14    Bose SoundSport Headphones
# 15            Macbook Pro Laptop
# 16                     iPhone 7s
# 17                   Samsung m10
# 18                      iPhone 7
# 19                   Samsung m10
# 20              Wired Headphones
# 21              27in FHD Monitor
# 22                     iPhone 11
# 23              27in FHD Monitor
# 24                      LG Dryer
# Name: Product, dtype: object

# %%
#select multiple column
import pandas as pd
df=pd.read_csv("Sales1.tsv",sep="\t")
df1=["Customer Name","Product"]
df2=df[df1]
print(df2)
# Out:
#    Customer Name                     Product
# 0          Veeru      34in Ultrawide Monitor
# 1          Tarun                 Samsung m10
# 2          Kedar                20in Monitor
# 3        Lavanya                   iPhone 11
# 4           Venu          Macbook Pro Laptop
# 5           Venu  Bose SoundSport Headphones
# 6         Harsha      27in 4K Gaming Monitor
# 7         Harsha                 Samsung m10
# 8         Siddhu      34in Ultrawide Monitor
# 9         Siddhu                   iPhone 11
# 10          Venu                 Samsung m10
# 11       Karteek          Macbook Pro Laptop
# 12        Shahid             ThinkPad Laptop
# 13        Siddhu      27in 4K Gaming Monitor
# 14  Jaya Chandra  Bose SoundSport Headphones
# 15  Jaya Chandra          Macbook Pro Laptop
# 16     Madhurima                   iPhone 7s
# 17         Kedar                 Samsung m10
# 18         Tarun                    iPhone 7
# 19       Sumanth                 Samsung m10
# ...

# %%
#select single column ,apply total
import pandas as pd
df=pd.read_csv("Sales1.tsv",sep="\t")
total=df['Quantity'].sum()
print(total)
# Out:
# 37

# %%
#select specific customer
import pandas as pd
df=pd.read_csv("Sales1.tsv",sep="\t")
cut_name=df[df['Customer Name']=='Lavanya']
print(cut_name)
# Out:
#    Order ID Customer Name    Product  Quantity
# 3    166840       Lavanya  iPhone 11         3

# %%
#selecting specific product
import pandas as pd
df=pd.read_csv('Sales1.tsv',sep="\t")
Prod_name=df[df['Product']=='Macbook Pro Laptop']
print(Prod_name)
# Out:
#     Order ID Customer Name             Product  Quantity
# 4     166841          Venu  Macbook Pro Laptop         2
# 11    166848       Karteek  Macbook Pro Laptop         1
# 15    166851  Jaya Chandra  Macbook Pro Laptop         1

# %%
#iLOC[]
#slecting single column
import pandas as pd
df1=pd.read_csv('Sales1.tsv',sep="\t")
s=df1.iloc[2]
print(s)
# Out:
# Order ID               166839
# Customer Name           Kedar
# Product          20in Monitor
# Quantity                    1
# Name: 2, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('Sales1.tsv',sep="\t")
s=df1.iloc[:,2]
print(s)
# Out:
# 0         34in Ultrawide Monitor
# 1                    Samsung m10
# 2                   20in Monitor
# 3                      iPhone 11
# 4             Macbook Pro Laptop
# 5     Bose SoundSport Headphones
# 6         27in 4K Gaming Monitor
# 7                    Samsung m10
# 8         34in Ultrawide Monitor
# 9                      iPhone 11
# 10                   Samsung m10
# 11            Macbook Pro Laptop
# 12               ThinkPad Laptop
# 13        27in 4K Gaming Monitor
# 14    Bose SoundSport Headphones
# 15            Macbook Pro Laptop
# 16                     iPhone 7s
# 17                   Samsung m10
# 18                      iPhone 7
# 19                   Samsung m10
# 20              Wired Headphones
# 21              27in FHD Monitor
# 22                     iPhone 11
# 23              27in FHD Monitor
# 24                      LG Dryer
# Name: Product, dtype: object

# %%
#selecting multiple rows and colums
import pandas as pd
df=pd.read_csv('Sales1.tsv',sep="\t")
s=df.iloc[0:3,1:3]
print(s)
# Out:
#   Customer Name                 Product
# 0         Veeru  34in Ultrawide Monitor
# 1         Tarun             Samsung m10
# 2         Kedar            20in Monitor

# %%
import pandas as pd
df=pd.read_csv('Sales1.tsv',sep="\t")
df1.set_index("Customer Name",inplace=True)
print(s)
# Out:
#   Customer Name                 Product
# 0         Veeru  34in Ultrawide Monitor
# 1         Tarun             Samsung m10
# 2         Kedar            20in Monitor

# %%
import pandas as pd
df=pd.read_csv('Sales1.tsv',sep="\t")
a=df['Product']=='LG Washing Machine'
df1=df.loc[1]
print(df1.head())
# Out:
# Order ID              166838
# Customer Name          Tarun
# Product          Samsung m10
# Quantity                   3
# Name: 1, dtype: object
